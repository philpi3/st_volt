# %%
import pandas as pd

# %%
# importing csv's

facebook24 = pd.read_csv(r"C:\Users\phil1\OneDrive\Volt\Data\Organic Social Media\Facebook_Content_2024.csv", delimiter=';')
facebook21 = pd.read_csv(r"C:\Users\phil1\OneDrive\Volt\Data\Organic Social Media\Facebook_Content_2021.csv", delimiter=';')
#facebook23 = pd.read_csv(r"C:\Users\phil1\OneDrive\Volt\Data\Organic Social Media\Facebook_Content_2023.csv", delimiter=';')

instagram24 = pd.read_csv(r"C:\Users\phil1\OneDrive\Volt\Data\Organic Social Media\Instagram_Content_2024.csv", delimiter=';')
instagram21 = pd.read_csv(r"C:\Users\phil1\OneDrive\Volt\Data\Organic Social Media\Instagram_Content_2021.csv", delimiter=';')
#instagram23 = pd.read_csv(r"C:\Users\phil1\OneDrive\Volt\Data\Organic Social Media\Instagram_Content_2023.csv", delimiter=';')

linkedin24 = pd.read_csv(r"C:\Users\phil1\OneDrive\Volt\Data\Organic Social Media\LinkedIn_Content_2024.csv", delimiter=';')
linkedin21 = pd.read_csv(r"C:\Users\phil1\OneDrive\Volt\Data\Organic Social Media\LinkedIn_Content_2021.csv", delimiter=';')
#linkedin23 = pd.read_csv(r"C:\Users\phil1\OneDrive\Volt\Data\Organic Social Media\LinkedIn_Content_2023.csv", delimiter=';')

tiktok24 = pd.read_csv(r"C:\Users\phil1\OneDrive\Volt\Data\Organic Social Media\TikTok_Content_2024.csv", delimiter=';')
#tiktok23 = pd.read_csv(r"C:\Users\phil1\OneDrive\Volt\Data\Organic Social Media\TikTok_Content_2023.csv", delimiter=';')

twitter24 = pd.read_csv(r"C:\Users\phil1\OneDrive\Volt\Data\Organic Social Media\Twitter_Content_2024.csv", delimiter=';')
twitter21 = pd.read_csv(r"C:\Users\phil1\OneDrive\Volt\Data\Organic Social Media\Twitter_Content_2021.csv", delimiter=';')
#twitter23 = pd.read_csv(r"C:\Users\phil1\OneDrive\Volt\Data\Organic Social Media\Twitter_Content_2023.csv", delimiter=';')

youtube24 = pd.read_csv(r"C:\Users\phil1\OneDrive\Volt\Data\Organic Social Media\YouTube_Content_2024.csv", delimiter=';')
youtube21 = pd.read_csv(r"C:\Users\phil1\OneDrive\Volt\Data\Organic Social Media\YouTube_Content_2021.csv", delimiter=';')
#youtube23 = pd.read_csv(r"C:\Users\phil1\OneDrive\Volt\Data\Organic Social Media\YouTube_Content_2023.csv", delimiter=';')

# %%
# concatenating dfs
instagram = pd.concat([instagram24, instagram21]).reset_index(drop=True)
facebook = pd.concat([facebook24, facebook21]).reset_index(drop=True)
linkedin = pd.concat([linkedin24, linkedin21]).reset_index(drop=True)
twitter = pd.concat([twitter24, twitter21]).reset_index(drop=True)
youtube = pd.concat([youtube24, youtube21]).reset_index(drop=True)

# %%
instagram.head()
# Out:
#              Datum             Profil  \
# 0  10.05.24, 12:30  Damian Boeselager
# 1  11.06.24, 11:49   Volt Deutschland
# 2  10.06.24, 13:36   Volt Deutschland
# 3  10.06.24, 20:03   Volt Deutschland
# 4  07.06.24, 12:10   Volt Deutschland
#
#                                            Nachricht Anzahl Likes  \
# 0                        I mean… 😂🇪🇺🫶🏼 #humor #reels      95049,0
# 1  Wir haben der AfD einen Sitz geklaut!😎\n\nDenn...      23862,0
# 2  Wow, danke für eure Stimmen! Über eine Million...      17587,0
# 3  Über eine Million Mal DANKE 💜\n\nBevor es für ...      10833,0
# 4  Jetzt wird’s lila! 💜 Volt steht bei der aktuel...       9324,0
#
#   Anzahl Kommentare Gesamtanzahl Reaktionen, Kommentare & Shares  \
# 0            3340,0                                      98389,0
# 1             310,0                                      24172,0
# 2             435,0                                      18022,0
# 3             282,0                                      11115,0
# ...

# %%
twitter.head()
# Out:
#              Datum           Profil  \
# 0  06.06.24, 22:28  VoltDeutschland
# 1  10.06.24, 14:06  VoltDeutschland
# 2  07.06.24, 12:26  VoltDeutschland
# 3  09.06.24, 09:20  VoltDeutschland
# 4  07.06.24, 11:19  VoltDeutschland
#
#                                            Nachricht Anzahl Likes  \
# 0  Volt bei 3% zur Europawahl! Jetzt wird’s lila....       1359,0
# 1  Wow, danke für eure Stimmen! Über eine Million...       1056,0
# 2  Jetzt wird’s lila! 💜 Volt steht bei der aktuel...        574,0
# 3  Jetzt kommt es drauf an! 💜 \nEs gibt keine Pro...        445,0
# 4  (at)Wahlen_DE Volt bei 3%! Yeees, jetzt wird's...        354,0
#
#   Anzahl Kommentare Gesamtanzahl Reaktionen, Kommentare & Shares  \
# 0             100,0                                       1674,0
# 1              50,0                                       1200,0
# 2              41,0                                        705,0
# 3              49,0                                        564,0
# ...

# %%
youtube.head()
# Out:
#              Datum            Profil  \
# 0  15.06.24, 17:30  Volt Deutschland
# 1  25.05.24, 11:00  Volt Deutschland
# 2  18.05.24, 16:15  Volt Deutschland
# 3  01.05.24, 11:00  Volt Deutschland
# 4  07.06.24, 15:30  Volt Deutschland
#
#                                            Nachricht Anzahl Likes  \
# 0  5 Sitze - Was jetzt? Was passiert nach der Eur...       3908,0
# 1  Volt vs. Grüne - Was ist der Unterschied? Part...       1793,0
# 2  #waswärewenn es die Vereinigten Staaten von Eu...       1677,0
# 3  MUT FÜR EUROPA - Volt Wahlwerbespot zur Europa...       1396,0
# 4  5% in 🇳🇱 & 3% in 🇩🇪 für Volt!\nDas ist so kras...       1376,0
#
#   Anzahl Kommentare Gesamtanzahl Reaktionen, Kommentare & Shares  \
# 0             408,0                                       4316,0
# 1             433,0                                       2226,0
# 2             389,0                                       2066,0
# 3             287,0                                       1683,0
# ...

# %%
facebook.head()
# Out:
#              Datum            Profil  \
# 0  11.06.24, 11:49  Volt Deutschland
# 1  10.06.24, 13:36  Volt Deutschland
# 2  07.06.24, 12:10  Volt Deutschland
# 3  12.06.24, 09:52  Volt Deutschland
# 4  07.06.24, 14:03  Volt Deutschland
#
#                                            Nachricht Anzahl Likes  \
# 0  Wir haben der AfD einen Sitz geklaut!😎\n\nDenn...        823,0
# 1  Wow, danke für eure Stimmen! Über eine Million...        694,0
# 2  Jetzt wird’s lila! 💜 Volt steht bei der aktuel...        427,0
# 3  9% aller Wähler*innen unter 30 haben Volt gewä...        331,0
# 4  Die Europawahlen könnten nicht besser starten!...        258,0
#
#   Anzahl Kommentare Gesamtanzahl Reaktionen, Kommentare & Shares  \
# 0             182,0                                       1217,0
# 1             105,0                                        981,0
# 2              43,0                                        586,0
# 3              75,0                                        439,0
# ...

# %%
linkedin.head()
# Out:
#              Datum            Profil  \
# 0  11.06.24, 12:03  volt-deutschland
# 1  10.06.24, 14:03  volt-deutschland
# 2  07.06.24, 12:16  volt-deutschland
# 3  07.06.24, 14:15  volt-deutschland
# 4  06.06.24, 23:39  volt-deutschland
#
#                                            Nachricht Anzahl Likes  \
# 0  Wir haben der AfD einen Sitz geklaut!😎\n\nDenn...       8204,0
# 1  Wow, danke für eure Stimmen! Über eine Million...       1280,0
# 2  Jetzt wird’s lila! 💜 Volt steht bei der aktuel...        610,0
# 3  Die Europawahlen könnten nicht besser starten!...        431,0
# 4          Wir stehen bei 3%! Jetzt wird es lila! 💜         397,0
#
#   Anzahl Kommentare Gesamtanzahl Reaktionen, Kommentare & Shares  \
# 0             180,0                                       8384,0
# 1              61,0                                       1341,0
# 2              41,0                                        651,0
# 3               7,0                                        438,0
# ...

# %%
### TO-DO
# [X] Column deletion 
# [?] concat all to one csv? -> add platform column
# [postponed] deal with NaN

# %%
# Fixing Columns
columns_to_keep = ['Datum', 'Profil', 'Nachricht', 'Anzahl Likes', 'Anzahl Kommentare',
       'Gesamtanzahl Reaktionen, Kommentare & Shares', 'Post-Interaktionsrate','Reichweite pro Post','Interaktionen pro Impression',
       'Profil-ID', 'Beitrag-ID', 'Link']

instagram_1 = instagram[columns_to_keep].copy()
facebook_1 = facebook[columns_to_keep].copy()
twitter_1 = twitter[columns_to_keep].copy()
linkedin_1 = linkedin[columns_to_keep].copy()
tiktok_1 = tiktok24[columns_to_keep].copy()
youtube_1 = youtube[columns_to_keep].copy()

# List of strings to add as columns
platforms = ['Instagram', 'Facebook','Twitter','LinkedIn','TikTok','YouTube']

# List of DataFrames
dfs = [instagram_1, facebook_1, twitter_1, linkedin_1, tiktok_1, youtube_1]

# Add a 'Platform' column with different values to each DataFrame
for i, df in enumerate(dfs):
    platform_value = platforms[i]
    dfs[i]['Platform'] = platform_value

# Resulting modified DataFrames
instagram_2 = dfs[0]
facebook_2 = dfs[1]
twitter_2 = dfs[2]
linkedin_2 = dfs[3]
tiktok_2 = dfs[4]
youtube_2 = dfs[5]

# %%
# Exporting csvs
instagram_2.to_csv(r'C:\Users\phil1\OneDrive\Volt\Data\Organic Social Media\instagram_content.csv')
facebook_2.to_csv(r'C:\Users\phil1\OneDrive\Volt\Data\Organic Social Media\facebook_content.csv')
twitter_2.to_csv(r'C:\Users\phil1\OneDrive\Volt\Data\Organic Social Media\twitter_content.csv')
linkedin_2.to_csv(r'C:\Users\phil1\OneDrive\Volt\Data\Organic Social Media\linkedin_content.csv')
tiktok_2.to_csv(r'C:\Users\phil1\OneDrive\Volt\Data\Organic Social Media\tiktok_content.csv')
youtube_2.to_csv(r'C:\Users\phil1\OneDrive\Volt\Data\Organic Social Media\youtube_content.csv')

# %%
# concatenating dfs to one
all_content = pd.concat([instagram_2, facebook_2, twitter_2, linkedin_2, tiktok_2, youtube_2]).reset_index(drop=True)
# Out:
#              Datum             Profil  \
# 0  10.05.24, 12:30  Damian Boeselager
# 1  11.06.24, 11:49   Volt Deutschland
# 2  10.06.24, 13:36   Volt Deutschland
# 3  10.06.24, 20:03   Volt Deutschland
# 4  07.06.24, 12:10   Volt Deutschland
#
#                                            Nachricht Anzahl Likes  \
# 0                        I mean… 😂🇪🇺🫶🏼 #humor #reels      95049,0
# 1  Wir haben der AfD einen Sitz geklaut!😎\n\nDenn...      23862,0
# 2  Wow, danke für eure Stimmen! Über eine Million...      17587,0
# 3  Über eine Million Mal DANKE 💜\n\nBevor es für ...      10833,0
# 4  Jetzt wird’s lila! 💜 Volt steht bei der aktuel...       9324,0
#
#   Anzahl Kommentare Gesamtanzahl Reaktionen, Kommentare & Shares  \
# 0            3340,0                                      98389,0
# 1             310,0                                      24172,0
# 2             435,0                                      18022,0
# 3             282,0                                      11115,0
# ...

# %%
all_content.to_csv(r'C:\Users\phil1\OneDrive\Volt\Data\Organic Social Media\all_content.csv')

# %%
# META
# import

meta_21 = pd.read_csv(r"C:\Users\phil1\OneDrive\Volt\Data\Digital Ads\META Reporting-Day-Campaign-AdGroup-Ad-26.5.-30.9.2021.csv")
meta_24 = pd.read_csv(r"C:\Users\phil1\OneDrive\Volt\Data\Digital Ads\META Reporting-Day-Campaigns-Ad Sets-Ads 1.1. - 17.6.2024.csv")
meta_23 = pd.read_csv(r"C:\Users\phil1\OneDrive\Volt\Data\Digital Ads\META-Reporting-Day-Campaign-AdGroup-Ad-1.1.2023-31.5.2023.csv")
meta_reporting_all = pd.read_csv(r"C:\Users\phil1\OneDrive\Volt\Data\Digital Ads\Reporting-All-Creatives (1).csv")

# %%
meta_21
# Out:
#              Day                 Campaign name  \
# 0            NaN                           NaN
# 1     2021-09-25  DE0000_BTW21_Run2_Conversion
# 2     2021-09-25   DE0000_BTW21_Run2_Awareness
# 3     2021-09-25   DE0000_BTW21_Run2_Awareness
# 4     2021-09-25   DE0000_BTW21_Run2_Awareness
# ...          ...                           ...
# 2280  2021-06-23                 DE0000_Events
# 2281  2021-06-22                 DE0000_Events
# 2282  2021-06-21                 DE0000_Events
# 2283  2021-06-20                 DE0000_Events
# 2284  2021-06-19                 DE0000_Events
#
#                                      Ad Set Name  \
# 0                                            NaN
# 1                DE0000_Run2_IG_WK3_m_Conversion
# 2                 DE0000_Run2_IG_WK3_m_Awareness
# 3             DE0000_Run2_IG_neu_WK1_w_Awareness
# 4                 DE0000_Run2_IG_WK2_m_Awareness
# ...                                          ...
# ...

# %%
meta_24
# Out:
#              Day               Campaign name  \
# 0            NaN                         NaN
# 1     2024-06-16  DE0000_Europawahl_ThruPlay
# 2     2024-06-16  DE0000_Europawahl_ThruPlay
# 3     2024-06-16  DE0000_Europawahl_ThruPlay
# 4     2024-06-15  DE0000_Europawahl_ThruPlay
# ...          ...                         ...
# 2367  2024-01-16        DE0000_MKampa_Phase2
# 2368  2024-01-16        DE0000_MKampa_Phase2
# 2369  2024-01-16        DE0000_MKampa_Phase2
# 2370  2024-01-16        DE0000_MKampa_Phase2
# 2371  2024-01-16        DE0000_MKampa_Phase2
#
#                                             Ad Set Name  \
# 0                                                   NaN
# 1     DE0000_Mitglieder-Kampagne_Story (ex Advertori...
# 2     DE0000_MitgliderK Postwahl_Feed (ex Advertoria...
# 3     DE0000_MitgliderK Postwahl_Feed (ex Advertoria...
# 4     DE0000_Mitglieder-Kampagne_Story (ex Advertori...
# ...                                                 ...
# ...

# %%
all_meta_ads = pd.concat([meta_21, meta_23, meta_24]).reset_index(drop=True)

# %%
all_meta_ads
# Out:
#              Day                 Campaign name  \
# 0            NaN                           NaN
# 1     2021-09-25  DE0000_BTW21_Run2_Conversion
# 2     2021-09-25   DE0000_BTW21_Run2_Awareness
# 3     2021-09-25   DE0000_BTW21_Run2_Awareness
# 4     2021-09-25   DE0000_BTW21_Run2_Awareness
# ...          ...                           ...
# 6424  2024-01-16          DE0000_MKampa_Phase2
# 6425  2024-01-16          DE0000_MKampa_Phase2
# 6426  2024-01-16          DE0000_MKampa_Phase2
# 6427  2024-01-16          DE0000_MKampa_Phase2
# 6428  2024-01-16          DE0000_MKampa_Phase2
#
#                                        Ad Set Name  \
# 0                                              NaN
# 1                  DE0000_Run2_IG_WK3_m_Conversion
# 2                   DE0000_Run2_IG_WK3_m_Awareness
# 3               DE0000_Run2_IG_neu_WK1_w_Awareness
# 4                   DE0000_Run2_IG_WK2_m_Awareness
# ...                                            ...
# ...

# %%
all_meta_ads.to_csv(r'C:\Users\phil1\OneDrive\Volt\Data\Digital Ads\all_meta_ads.csv')

# %%
# Google Ads
# Import

search_24 = pd.read_csv(r"C:\Users\phil1\OneDrive\Volt\Data\Digital Ads\SEARCH CAMPAIGNS -w Campaigns Time 1.1. - 17.6.2024.csv",skiprows=[0, 1], delimiter=',')
search_23 = pd.read_csv(r"C:\Users\phil1\OneDrive\Volt\Data\Digital Ads\SEARCH CAMPAIGNS -w Campaigns Time 1.1. - 31.12.2023.csv",skiprows=[0, 1], delimiter=',')
search_21 = pd.read_csv(r"C:\Users\phil1\OneDrive\Volt\Data\Digital Ads\SEARCH CAMPAIGNS -w Campaigns Time 29.7. - 30.09.2021.csv",skiprows=[0, 1], delimiter=',')

video_24 = pd.read_csv(r"C:\Users\phil1\OneDrive\Volt\Data\Digital Ads\VIDEO CAMPAIGNS -w campaign, ad set, ad Time 1.1.-17.6.2024.csv",skiprows=[0, 1], delimiter=',')
video_23 = pd.read_csv(r"C:\Users\phil1\OneDrive\Volt\Data\Digital Ads\VIDEO CAMPAIGNS -w campaigns, ad set, ad 2023.csv",skiprows=[0, 1], delimiter=',')
video_21 = pd.read_csv(r"C:\Users\phil1\OneDrive\Volt\Data\Digital Ads\VIDEO CAMPAIGNS -w campaign, ad set, ad 29.7.-30.9.2021.csv",skiprows=[0, 1], delimiter=',')

display_24 = pd.read_csv(r"C:\Users\phil1\OneDrive\Volt\Data\Digital Ads\DISPLAY CAMPAIGNS Time 1.1. - 17.6. 2024.csv",skiprows=[0, 1], delimiter=',')
display_21 = pd.read_csv(r"C:\Users\phil1\OneDrive\Volt\Data\Digital Ads\DISPLAY CAMPAIGNS Time 29.7. - 30.9. 2021.csv",skiprows=[0, 1], delimiter=',')

# %%
search_all = pd.concat([search_24, search_23, search_21]).reset_index(drop=True)
video_all = pd.concat([video_24, video_23, video_21]).reset_index(drop=True)
display_all = pd.concat([display_24, display_21]).reset_index(drop=True)

# %%
search_all
# Out:
#             Day                       Campaign  Clicks   Impr.     CTR  \
# 0    2024-05-06  DE0000 SEA | Brand Protection       9      55  16.36%
# 1    2024-05-07  DE0000 SEA | Brand Protection      27     346   7.80%
# 2    2024-05-08  DE0000 SEA | Brand Protection      93     498  18.67%
# 3    2024-05-09  DE0000 SEA | Brand Protection     201     469  42.86%
# 4    2024-05-10  DE0000 SEA | Brand Protection      10      21  47.62%
# ..          ...                            ...     ...     ...     ...
# 123  2021-09-23                   SEA I Berlin     112   2,242   5.00%
# 124  2021-09-24      01 SEA | Volt Deutschland  10,033  54,161  18.52%
# 125  2021-09-24                   SEA I Berlin      97   1,499   6.47%
# 126  2021-09-25      01 SEA | Volt Deutschland  10,488  52,531  19.97%
# 127  2021-09-25                   SEA I Berlin     134   2,293   5.84%
#
#     Currency code  Avg. CPC    Cost Impr. (Abs. Top) % Impr. (Top) %  \
# ...

# %%
#  export

search_all.to_csv(r'C:\Users\phil1\OneDrive\Volt\Data\Digital Ads\search_all.csv')
video_all.to_csv(r'C:\Users\phil1\OneDrive\Volt\Data\Digital Ads\video_all.csv')
display_all.to_csv(r'C:\Users\phil1\OneDrive\Volt\Data\Digital Ads\display_all.csv')
